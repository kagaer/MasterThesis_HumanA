# %%
import sqlite3
import pandas as pd
from pathlib import Path

import os
import math
import random
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import networkx as nx

# %%
# path to databases
"For which experiment would you like to add the density matrix to the database?"
experiment = int(input())
if experiment == 1:
    db_path = Path('E:/HumanA/Data/DataBase/HumanA_Exp1.db')
    #db_path = Path('E:/HumanA/Data/HumanA_Exp1_WorkingData.db')
elif experiment == 2:
    db_path = Path('E:/HumanA/Data/DataBase/HumanA_Exp2.db')
    #db_path = Path('E:/HumanA/Data/HumanA_Exp2_WorkingData.db')
# Out:
# 2

# %%
# check if path exists
if not db_path or not db_path.exists():
    db_path = ':memory:'

# %%
def create_density_matrix(coordinates, meters):
    xmin = coordinates["x"].min()
    xmax = coordinates["x"].max()
    zmin = coordinates["z"].min()
    zmax = coordinates["z"].max()
    step = meters
    xsize = int((np.abs(xmin) + np.abs(xmax)) / step) + 1
    zsize = int((np.abs(zmin) + np.abs(zmax)) / step) + 1
    density_matrix = np.zeros((xsize,zsize), dtype=np.int64)
    i = 0
    for coordinate in coordinates[["x", "z"]].to_numpy():
        x = int((np.abs(xmin) + coordinate[0]) / step)
        y = int((np.abs(zmin) + coordinate[1]) / step)
        density_matrix[x,y] += 1
        i += 1
    return density_matrix

# %%
def convert_coordinate(coordinate, meters):
    step = meters
    xsize = int((np.abs(xmin) + np.abs(xmax)) / step) + 1
    zsize = int((np.abs(zmin) + np.abs(zmax)) / step) + 1
    x = int((np.abs(xmin) + coordinate[0]) / step)
    y = int((np.abs(zmin) + coordinate[1]) / step)
    return x, y

# %%
def rotate_matrix(matrix):
    return np.rot90(np.flip(matrix, axis=0), k=-1)

# %%
def create_matrix(step, xmin, xmax, zmin,zmax):
    xsize = int((np.abs(xmin) + np.abs(xmax)) / step) + 1
    zsize = int((np.abs(zmin) + np.abs(zmax)) / step) + 1
    density_matrix = np.zeros((xsize,zsize), dtype=np.int64)
    return density_matrix

# %%
def create_trial_matrix(coordinates, meters, xmin, xmax, zmin, zmax):
    step = meters
    trial_matrix = create_matrix(step = step, xmin = xmin, xmax = xmax, zmin = zmin, zmax = zmax)
    #print(trial_matrix.shape)
    i = 0
    for coordinate in coordinates[["x", "z"]].to_numpy():
        x = int((np.abs(xmin) + coordinate[0]) / step)
        y = int((np.abs(zmin) + coordinate[1]) / step)
        trial_matrix[x,y] += 1
        i += 1
    return trial_matrix

# %%
# connect to database
connection=sqlite3.connect(db_path)
cr=connection.cursor()

# read data from SQL to pandas dataframe.
sql_instruction = """
SELECT DISTINCT participantId FROM trials WHERE validParticipant = 'VALID';
"""
cr.execute(sql_instruction)
participants = cr.fetchall()

# %%
# create a table that stores the mask information
sql_instruction = """
CREATE TABLE IF NOT EXISTS "density_map_participants"(
"Id" INTEGER NOT NULL UNIQUE,
"TrialId" INTEGER NOT NULL,
"Row" NUMERIC,
"Column" NUMERIC,
"Value" NUMERIC,
PRIMARY KEY ("Id" AUTOINCREMENT)
FOREIGN KEY(TrialId) REFERENCES trials(Id)
);
"""
cr.execute(sql_instruction)

# %%
connection.commit()

# %%
sql_instruction = """
SELECT MIN(playerBodyPosition_x) FROM data_points;
"""
cr.execute(sql_instruction)

xMin = cr.fetchone()
xMin = round(xMin[0],2)
print(xMin)
# Out:
# -442.87

# %%
sql_instruction = """
SELECT MAX(playerBodyPosition_x) FROM data_points;
"""
cr.execute(sql_instruction)

xMax = cr.fetchone()
xMax = round(xMax[0],2)
print(xMax)
# Out:
# 439.76

# %%
sql_instruction = """
SELECT MIN(playerBodyPosition_z) FROM data_points;
"""
cr.execute(sql_instruction)

zMin = cr.fetchone()
zMin = round(zMin[0],2)
print(zMin)
# Out:
# -293.49

# %%
sql_instruction = """
SELECT MAX(playerBodyPosition_z) FROM data_points;
"""
cr.execute(sql_instruction)

zMax = cr.fetchone()
zMax = round(zMax[0],2)
print(zMax)
# Out:
# 305.67

# %%
# connect to database
#connection=sqlite3.connect(db_path_exp1)
#cr=connection.cursor()
density_matrix = create_matrix(step = 4, xmin = xMin, xmax = xMax, zmin = zMin, zmax = zMax)
for participant in participants:
    participant = participant[0]
    
    sql_instruction = f"""
    SELECT DISTINCT id 
    FROM trials
    WHERE participantId = {participant};
    """
    cr.execute(sql_instruction)
    trialId = cr.fetchall()
    #print(trialId_exp1)
    #trialId_exp1 = trialId_exp1[0]
    #print(trialId_exp1)
    for trialId in trialId:
        trialId = trialId[0]
        
        sql_instruction = """SELECT DISTINCT TrialId FROM density_map_participants"""
        cr.execute(sql_instruction)
        trial_idx = cr.fetchall()
        if (trialId,) not in trial_idx:
            print("Participant: " + str(participant) + " | " + "TrialId: " + str(trialId))

            # get relevant data (participant ID, sessionNr, timestamp, x,y,z coordinates) from database for current trial
            sql_instruction = f"""
            SELECT trials.participantId, trials.sessionNr, data_points.timeStampDataPointStart, 
                data_points.playerBodyPosition_x, data_points.playerBodyPosition_y, 
                data_points.playerBodyPosition_z
            FROM trials
            LEFT JOIN data_points ON trials.id = data_points.trialId
            WHERE trials.id = {trialId}
            ;
            """

            tracking_data = pd.read_sql_query(sql_instruction, connection)
            
            # rename columns 
            tracking_data.columns = ['participant', 'session', 'time', 'x', 'y', 'z']
            
            # round coordinates to 2 digits
            tracking_data["x"] = tracking_data["x"].round(2)
            tracking_data["z"] = tracking_data["z"].round(2)
            

            # create density matrix for trial
            density_matrix_trial = create_trial_matrix(coordinates=tracking_data, meters=4, xmin = xMin, 
                                                       xmax = xMax, zmin = zMin, zmax = zMax)
        
            # get density matrix values & store in database (every value that is not 0)
            for row in range(density_matrix_trial.shape[0]):
                for column in range(density_matrix_trial.shape[1]):
                    if density_matrix_trial[row][column] != 0:
                        value = str((trialId,row,column, density_matrix_trial[row][column]))
                        sql_instruction = f"""INSERT INTO density_map_participants (TrialId, Row, Column, Value) VALUES {value};"""
                        cr.execute(sql_instruction)
            connection.commit()

    #print("Do you want to continue (next participant) ?")
    #_continue = input()
    #if _continue == "Yes":
    #    continue
    #else:
    #    break
print("done")
#connection.close()
# Out:
# Participant: 1754 | TrialId: 7
# Participant: 1754 | TrialId: 9
# Participant: 1754 | TrialId: 11
# Participant: 1754 | TrialId: 13
# Participant: 1754 | TrialId: 15
# Participant: 1754 | TrialId: 18
# Participant: 1754 | TrialId: 21
# Participant: 1754 | TrialId: 23
# Participant: 1754 | TrialId: 25
# Participant: 1754 | TrialId: 27
# Participant: 1754 | TrialId: 29
# Participant: 1754 | TrialId: 32
# Participant: 1754 | TrialId: 36
# Participant: 1754 | TrialId: 40
# Participant: 1754 | TrialId: 44
# Participant: 2258 | TrialId: 16
# Participant: 2258 | TrialId: 19
# Participant: 2258 | TrialId: 22
# Participant: 2258 | TrialId: 24
# Participant: 2258 | TrialId: 26
# Participant: 2258 | TrialId: 28
# Participant: 2258 | TrialId: 31
# Participant: 2258 | TrialId: 34
# Participant: 2258 | TrialId: 37
# Participant: 2258 | TrialId: 41
# Participant: 2258 | TrialId: 45
# Participant: 2258 | TrialId: 49
# Participant: 2258 | TrialId: 53
# Participant: 2258 | TrialId: 57
# Participant: 2258 | TrialId: 62
# Participant: 2693 | TrialId: 38
# Participant: 2693 | TrialId: 42
# Participant: 2693 | TrialId: 46
# Participant: 2693 | TrialId: 50
# Participant: 2693 | TrialId: 54
# Participant: 2693 | TrialId: 59
# Participant: 2693 | TrialId: 64
# Participant: 2693 | TrialId: 69
# Participant: 2693 | TrialId: 74
# Participant: 2693 | TrialId: 78
# Participant: 2693 | TrialId: 82
# Participant: 2693 | TrialId: 86
# Participant: 2693 | TrialId: 89
# Participant: 2693 | TrialId: 93
# Participant: 2693 | TrialId: 97
# Participant: 2693 | TrialId: 387
# Participant: 4176 | TrialId: 102
# Participant: 4176 | TrialId: 106
# Participant: 4176 | TrialId: 111
# Participant: 4176 | TrialId: 115
# Participant: 4176 | TrialId: 120
# Participant: 4176 | TrialId: 124
# Participant: 4176 | TrialId: 127
# Participant: 4176 | TrialId: 132
# Participant: 4176 | TrialId: 136
# Participant: 4176 | TrialId: 139
# Participant: 4176 | TrialId: 142
# Participant: 4176 | TrialId: 145
# Participant: 4176 | TrialId: 148
# Participant: 4176 | TrialId: 151
# Participant: 4176 | TrialId: 154
# Participant: 4796 | TrialId: 108
# Participant: 4796 | TrialId: 113
# Participant: 4796 | TrialId: 118
# Participant: 4796 | TrialId: 122
# Participant: 4796 | TrialId: 126
# Participant: 4796 | TrialId: 130
# Participant: 4796 | TrialId: 134
# Participant: 4796 | TrialId: 137
# Participant: 4796 | TrialId: 140
# Participant: 4796 | TrialId: 143
# Participant: 4796 | TrialId: 146
# Participant: 4796 | TrialId: 149
# Participant: 4796 | TrialId: 152
# Participant: 4796 | TrialId: 155
# Participant: 4796 | TrialId: 157
# Participant: 4917 | TrialId: 116
# Participant: 4917 | TrialId: 119
# Participant: 4917 | TrialId: 123
# Participant: 4917 | TrialId: 128
# Participant: 4917 | TrialId: 131
# Participant: 4917 | TrialId: 135
# Participant: 4917 | TrialId: 138
# Participant: 4917 | TrialId: 141
# Participant: 4917 | TrialId: 144
# Participant: 4917 | TrialId: 147
# Participant: 4917 | TrialId: 150
# Participant: 4917 | TrialId: 153
# Participant: 4917 | TrialId: 156
# Participant: 4917 | TrialId: 158
# Participant: 4917 | TrialId: 159
# Participant: 5238 | TrialId: 160
# Participant: 5238 | TrialId: 161
# Participant: 5238 | TrialId: 162
# Participant: 5238 | TrialId: 163
# Participant: 5238 | TrialId: 164
# Participant: 5238 | TrialId: 166
# Participant: 5238 | TrialId: 168
# Participant: 5238 | TrialId: 170
# Participant: 5238 | TrialId: 172
# Participant: 5238 | TrialId: 175
# Participant: 5238 | TrialId: 178
# Participant: 5238 | TrialId: 181
# Participant: 5238 | TrialId: 374
# Participant: 5238 | TrialId: 375
# Participant: 5238 | TrialId: 376
# Participant: 5741 | TrialId: 173
# Participant: 5741 | TrialId: 176
# Participant: 5741 | TrialId: 179
# Participant: 5741 | TrialId: 182
# Participant: 5741 | TrialId: 185
# Participant: 5741 | TrialId: 188
# Participant: 5741 | TrialId: 192
# Participant: 5741 | TrialId: 196
# Participant: 5741 | TrialId: 200
# Participant: 5741 | TrialId: 205
# Participant: 5741 | TrialId: 211
# Participant: 5741 | TrialId: 217
# Participant: 5741 | TrialId: 224
# Participant: 5741 | TrialId: 427
# Participant: 5741 | TrialId: 428
# Participant: 5741 | TrialId: 429
# Participant: 5741 | TrialId: 430
# Participant: 6642 | TrialId: 184
# Participant: 6642 | TrialId: 187
# Participant: 6642 | TrialId: 190
# Participant: 6642 | TrialId: 194
# Participant: 6642 | TrialId: 197
# Participant: 6642 | TrialId: 201
# Participant: 6642 | TrialId: 206
# Participant: 6642 | TrialId: 212
# Participant: 6642 | TrialId: 218
# Participant: 6642 | TrialId: 225
# Participant: 6642 | TrialId: 232
# Participant: 6642 | TrialId: 239
# Participant: 6642 | TrialId: 247
# Participant: 6642 | TrialId: 256
# Participant: 6642 | TrialId: 266
# Participant: 6642 | TrialId: 432
# Participant: 7093 | TrialId: 191
# Participant: 7093 | TrialId: 195
# Participant: 7093 | TrialId: 199
# Participant: 7093 | TrialId: 203
# Participant: 7093 | TrialId: 208
# Participant: 7093 | TrialId: 214
# Participant: 7093 | TrialId: 220
# Participant: 7093 | TrialId: 227
# Participant: 7093 | TrialId: 234
# Participant: 7093 | TrialId: 241
# Participant: 7093 | TrialId: 249
# Participant: 7093 | TrialId: 258
# Participant: 7093 | TrialId: 270
# Participant: 7093 | TrialId: 288
# Participant: 7093 | TrialId: 299
# Participant: 7093 | TrialId: 433
# Participant: 7412 | TrialId: 204
# Participant: 7412 | TrialId: 209
# Participant: 7412 | TrialId: 215
# Participant: 7412 | TrialId: 221
# Participant: 7412 | TrialId: 228
# Participant: 7412 | TrialId: 236
# Participant: 7412 | TrialId: 243
# Participant: 7412 | TrialId: 251
# Participant: 7412 | TrialId: 261
# Participant: 7412 | TrialId: 273
# Participant: 7412 | TrialId: 283
# Participant: 7412 | TrialId: 294
# Participant: 7412 | TrialId: 305
# Participant: 7412 | TrialId: 314
# Participant: 7412 | TrialId: 323
# Participant: 7842 | TrialId: 210
# Participant: 7842 | TrialId: 216
# Participant: 7842 | TrialId: 223
# Participant: 7842 | TrialId: 230
# Participant: 7842 | TrialId: 237
# Participant: 7842 | TrialId: 245
# Participant: 7842 | TrialId: 254
# Participant: 7842 | TrialId: 265
# Participant: 7842 | TrialId: 277
# Participant: 7842 | TrialId: 287
# Participant: 7842 | TrialId: 298
# Participant: 7842 | TrialId: 309
# Participant: 7842 | TrialId: 318
# Participant: 7842 | TrialId: 327
# Participant: 7842 | TrialId: 335
# Participant: 8007 | TrialId: 222
# Participant: 8007 | TrialId: 229
# Participant: 8007 | TrialId: 235
# Participant: 8007 | TrialId: 242
# Participant: 8007 | TrialId: 250
# Participant: 8007 | TrialId: 259
# Participant: 8007 | TrialId: 269
# Participant: 8007 | TrialId: 280
# Participant: 8007 | TrialId: 291
# Participant: 8007 | TrialId: 302
# Participant: 8007 | TrialId: 312
# Participant: 8007 | TrialId: 320
# Participant: 8007 | TrialId: 331
# Participant: 8007 | TrialId: 338
# Participant: 8007 | TrialId: 346
# Participant: 8469 | TrialId: 231
# Participant: 8469 | TrialId: 238
# Participant: 8469 | TrialId: 246
# Participant: 8469 | TrialId: 255
# Participant: 8469 | TrialId: 264
# Participant: 8469 | TrialId: 275
# Participant: 8469 | TrialId: 285
# Participant: 8469 | TrialId: 296
# Participant: 8469 | TrialId: 307
# Participant: 8469 | TrialId: 316
# Participant: 8469 | TrialId: 325
# Participant: 8469 | TrialId: 332
# Participant: 8469 | TrialId: 339
# Participant: 8469 | TrialId: 342
# Participant: 8469 | TrialId: 350
# Participant: 8469 | TrialId: 354
# Participant: 8673 | TrialId: 244
# Participant: 8673 | TrialId: 252
# Participant: 8673 | TrialId: 262
# Participant: 8673 | TrialId: 272
# Participant: 8673 | TrialId: 282
# Participant: 8673 | TrialId: 293
# Participant: 8673 | TrialId: 304
# Participant: 8673 | TrialId: 313
# Participant: 8673 | TrialId: 322
# Participant: 8673 | TrialId: 329
# Participant: 8673 | TrialId: 337
# Participant: 8673 | TrialId: 345
# Participant: 8673 | TrialId: 352
# Participant: 8673 | TrialId: 357
# Participant: 8673 | TrialId: 363
# Participant: 8695 | TrialId: 253
# Participant: 8695 | TrialId: 263
# Participant: 8695 | TrialId: 274
# Participant: 8695 | TrialId: 284
# Participant: 8695 | TrialId: 295
# Participant: 8695 | TrialId: 306
# Participant: 8695 | TrialId: 315
# Participant: 8695 | TrialId: 324
# Participant: 8695 | TrialId: 333
# Participant: 8695 | TrialId: 341
# Participant: 8695 | TrialId: 348
# Participant: 8695 | TrialId: 355
# Participant: 8695 | TrialId: 371
# Participant: 8695 | TrialId: 372
# Participant: 8695 | TrialId: 373
# Participant: 9472 | TrialId: 260
# Participant: 9472 | TrialId: 271
# Participant: 9472 | TrialId: 281
# Participant: 9472 | TrialId: 292
# Participant: 9472 | TrialId: 303
# Participant: 9472 | TrialId: 311
# Participant: 9472 | TrialId: 321
# Participant: 9472 | TrialId: 330
# Participant: 9472 | TrialId: 340
# Participant: 9472 | TrialId: 347
# Participant: 9472 | TrialId: 353
# Participant: 9472 | TrialId: 359
# Participant: 9472 | TrialId: 361
# Participant: 9472 | TrialId: 365
# Participant: 9472 | TrialId: 367
# Participant: 9601 | TrialId: 276
# Participant: 9601 | TrialId: 286
# Participant: 9601 | TrialId: 297
# Participant: 9601 | TrialId: 308
# Participant: 9601 | TrialId: 317
# Participant: 9601 | TrialId: 326
# Participant: 9601 | TrialId: 334
# Participant: 9601 | TrialId: 343
# Participant: 9601 | TrialId: 349
# Participant: 9601 | TrialId: 356
# Participant: 9601 | TrialId: 360
# Participant: 9601 | TrialId: 364
# Participant: 9601 | TrialId: 366
# Participant: 9601 | TrialId: 368
# Participant: 9601 | TrialId: 369
# Participant: 365 | TrialId: 377
# Participant: 365 | TrialId: 378
# Participant: 365 | TrialId: 379
# Participant: 365 | TrialId: 380
# Participant: 365 | TrialId: 381
# Participant: 365 | TrialId: 382
# Participant: 365 | TrialId: 383
# Participant: 365 | TrialId: 384
# Participant: 365 | TrialId: 385
# Participant: 365 | TrialId: 388
# Participant: 365 | TrialId: 389
# Participant: 365 | TrialId: 390
# Participant: 365 | TrialId: 391
# Participant: 365 | TrialId: 392
# Participant: 365 | TrialId: 393
# Participant: 365 | TrialId: 394
# Participant: 4597 | TrialId: 403
# Participant: 4597 | TrialId: 404
# Participant: 4597 | TrialId: 405
# Participant: 4597 | TrialId: 406
# Participant: 4597 | TrialId: 407
# Participant: 4597 | TrialId: 408
# Participant: 4597 | TrialId: 409
# Participant: 4597 | TrialId: 410
# Participant: 4597 | TrialId: 411
# Participant: 4597 | TrialId: 412
# Participant: 4597 | TrialId: 413
# Participant: 4597 | TrialId: 414
# Participant: 4597 | TrialId: 415
# Participant: 4597 | TrialId: 416
# Participant: 4597 | TrialId: 417
# Participant: 9586 | TrialId: 440
# Participant: 9586 | TrialId: 441
# Participant: 9586 | TrialId: 442
# Participant: 9586 | TrialId: 443
# Participant: 9586 | TrialId: 444
# Participant: 9586 | TrialId: 445
# Participant: 9586 | TrialId: 446
# Participant: 9586 | TrialId: 447
# Participant: 9586 | TrialId: 448
# Participant: 9586 | TrialId: 449
# Participant: 9586 | TrialId: 450
# Participant: 9586 | TrialId: 451
# Participant: 9586 | TrialId: 452
# Participant: 9586 | TrialId: 453
# Participant: 9586 | TrialId: 454
# done

# %% [markdown]
# ## Create full density Matrix and save to Database

# %%
sql_instruction = """SELECT Row, Column, SUM(Value) AS Value FROM density_map_participants GROUP BY Row, Column;"""
cr.execute(sql_instruction)
density_matrix_db = cr.fetchall()

# %%
density_matrix = create_matrix(step = 4, xmin = xMin, xmax = xMax, zmin = zMin, zmax = zMax)

# %%
for row in range(density_matrix.shape[0]):
    for column in range(density_matrix.shape[1]):
        for datapoint in density_matrix_db:
            if datapoint[0] == row and datapoint[1] == column:
                #print("Row: " + str(row) + " | Column: " + str(column) + " | value: " + str(datapoint[2]))
                density_matrix[row][column] = datapoint[2]

# %%
# create a table that stores general graph information
sql_instruction = """
CREATE TABLE IF NOT EXISTS "matrix_information"
("Id" INTEGER NOT NULL UNIQUE,
"Matrix_Name" TEXT NOT NULL,
PRIMARY KEY ("Id" AUTOINCREMENT))
"""
cr.execute(sql_instruction)

# %%
# create a table that stores the complete density matrix
sql_instruction = """
CREATE TABLE IF NOT EXISTS "density_matrix"(
"Id" INTEGER NOT NULL UNIQUE,
"MatrixId" INTEGER NOT NULL,
"Row" NUMERIC,
"Column" NUMERIC,
"Value" NUMERIC,
PRIMARY KEY ("Id" AUTOINCREMENT)
FOREIGN KEY(MatrixId) REFERENCES matrix_information(Id)
);
"""
cr.execute(sql_instruction)

# %%
matrix_in_databank = False

# %%
if not matrix_in_databank:
    #set_up_DB()
    
    # add the graph to the general table
    sql_instruction = """
    INSERT INTO matrix_information (Matrix_Name)
    VALUES ("Density_Matrix")
    """
    cr.execute(sql_instruction)
    
    # get the id from the graph
    cr.execute("""SELECT Id FROM matrix_information WHERE Matrix_Name = 'Density_Matrix'""")
    matrixId = cr.fetchone()
    matrixId = matrixId[0]
    
    # get mask information & store in database
    for row in range(density_matrix.shape[0]): #print(i)
        for column in range(density_matrix.shape[1]):
            value = str((matrixId,row,column, density_matrix[row][column]))
            sql_instruction = f"""INSERT INTO density_matrix (MatrixId, Row, Column, Value) VALUES {value};"""
            cr.execute(sql_instruction)
    connection.commit()
connection.close()
